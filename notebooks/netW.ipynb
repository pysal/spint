# %%
import numpy as np
from spintW import mat2L, netW

# %%
link_list = [
    ("a", "b"),
    ("a", "c"),
    ("a", "d"),
    ("b", "a"),
    ("b", "c"),
    ("b", "d"),
    ("c", "a"),
    ("c", "b"),
    ("c", "d"),
    ("d", "a"),
    ("d", "b"),
    ("d", "c"),
]

# %%
w = netW(link_list)
w.full()[0]

# %%
w = netW(link_list, share="O")
w.full()[0]

# %%
w = netW(link_list, share="D")
w.full()[0]

# %%
w = netW(link_list, share="OD")
w.full()[0]

# %%
w = netW(link_list, share="C")
w.full()[0]

# %%
mat = np.array([[0, 1, 1], [1, 0, 1], [1, 1, 0]])
mat

# %%
adj_l = mat2L(mat)
adj_l

# %%
w = netW(adj_l, share="C")
w.full()[0]
